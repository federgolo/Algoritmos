# %%
from matplotlib import pyplot
import numpy as np
import time, statistics

#salida obtenida en repl.it:
# java version "1.8.0_31"
# Java(TM) SE Runtime Environment (build 1.8.0_31-b13)
# Java HotSpot(TM) 64-Bit Server VM (build 25.31-b07, mixed mode)
a = [[6.868686868686869E-9], [5.175879396984925E-9], [2.7053140096618357E-9], [2.167919799498747E-9], [2.824849699398798E-9], [2.9308106102763864E-9], [2.9418119179002075E-9], [3.0491239048811013E-9], [3.0151471456625327E-9], [3.3277277277277275E-9]]

#salida obtenida en laptop marca Acer:
#procedador intel i5-5200U y 4GB de memoria RAM DDR3 L 
#NetBeans IDE 8.1 (Build 201510222201) - Java: 1.8.0_73; Java HotSpot(TM) Client VM 25.73-b02
#System: Windows 8.1 version 6.3 running on x86
list = [[2.424242424242424E-9], [1.256281407035176E-9], [1.26347082868822E-9], [1.4473684210526317E-9], [1.3466933867735471E-9], [1.8122797254683734E-9], [1.7552772181834106E-9], [1.7443679599499374E-9], [2.3466402999217237E-9], [1.8258258258258257E-9]]


r = range(0, len(a))

pyplot.plot([50*(i+1) for i in r], [list[i] for i in r], marker='o', label="Personal Computer")
pyplot.plot([50*(i+1) for i in r], [a[i] for i in r] , marker='D', label="repl.it")
pyplot.legend(loc='upper right')

pyplot.axhline(0, color="black")
pyplot.axvline(0, color="black")

pyplot.title("Tiempo por instrucción en función de n")   # Establece el título del gráfico
pyplot.xlabel("Lado de la matriz (n)")   # Inserta el título del eje X 
pyplot.ylabel("Tiempo por instrucción")   # Inserta el título del eje Y

# Guardar gráfico como imágen PNG.
pyplot.savefig("matrixJava2.png")
# Mostrarlo.
pyplot.show()
